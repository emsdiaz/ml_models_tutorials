# %% [markdown]
# # Decision Tree example - Regression

# %% [markdown]
# - **Purpose:** Predict Boston housing prices using census data
# - **Data:** Boston Housing prices. For more info follow <a href="https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html#:~:text=The%20Boston%20Housing%20Dataset,the%20area%20of%20Boston%20Mass." target="_blank">this link</a>
# - **Author:** Emily Diaz Badilla
# - **Date:** October 6th of 2020

# %% [markdown]
# Process steps:
# 1. [Import modules](#importmod)
# 2. [Load data](#loaddata)
# 3. [Profiling](#profiling)
# 4. [Data prep](#dataprep)
# 5. [Modeling](#modeling)

# %% [markdown]
# Useful links and sources:
# - https://towardsdatascience.com/baby-steps-towards-data-science-decision-tree-regression-in-python-323beeacbb6e
# - https://scikit-learn.org/stable/modules/tree.html
# - https://www.datasciencecentral.com/profiles/blogs/introduction-to-classification-regression-trees-cart#:~:text=A%20simple%20example%20of%20a,be%20split%20no%20more%3B%20and
# - https://en.wikipedia.org/wiki/Decision_tree_learning
# - https://sefiks.com/2018/08/27/a-step-by-step-cart-decision-tree-example/

# %% [markdown]
# # What is a Decision Tree

# %% [markdown]
# <img src="img/DT_example.png" />

# %% [markdown]
# Decision Tree is a *Supervised Learning* technique that can be used for **classification and regression** problems. The most popular type is called **CART** (Classification and Regression Trees). The algorithm is structured as a sequence of questions, that returns a tree like structure where the ends are terminal nodes at which point there are no more questions and we get the final result (category or numeric) for that set of characteristics.
#
# The metric that it considers to find the best split is **GINI impurity**, which is a measure of how often a randomly chosen element from the set would be incorrectly labeled if it was randomly labeled according to the distribution of labels in the subset.
#
# Other important characteristics of this method are:
# - CART is nonparametric and therefore does not rely on data belonging to a particular type of distribution
# - CART is not significantly impacted by outliers in the input variables
# - CART can use the same variables more than once in different parts of the tree.  This capability can uncover complex interdependencies between sets of variables
# - Is the base for more complex ensemble and boosting methods such as Random Forest and GBM
#
# Disadvantages:
# - Trees are very sensitive to small change in the training data leading to significant changes on final predictions (robustness issue)
# - They tend to overfit (can be solved with pruning)

# %% [markdown]
# ***

# %% [markdown]
# <a id="importmod"></a>
# ## 1. Import modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport # profiling. Using version 2.1, 3 didn't work
from sklearn.preprocessing import MinMaxScaler # scaling data to 0-1 range
from sklearn.model_selection import train_test_split #train/test split
from sklearn.tree import DecisionTreeRegressor # to create decision tree
from sklearn import tree # to plot tree
from sklearn.model_selection import cross_val_score # to obtain accuracy of model
from sklearn.model_selection import GridSearchCV # for parameter tuning

# %%
# Random seed: to always get the same results/reproducibility
random_seed = 1234

# %%
# Functions
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
directory = "./1_Input/"

# %% [markdown]
# <a id="loaddata"></a>
# ## 2. Load data

# %%
filename = (directory + "housing.csv")
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
dataset = pd.read_csv(filename, delim_whitespace=True, names=names)
print(dataset.shape)
dataset.head()
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# <a id="profiling"></a>
# ## 3. Profiling

# %% [markdown]
# For more info about this package, follow <a href="https://github.com/pandas-profiling/pandas-profiling" target="_blank">this link</a>

# %%
# profile = ProfileReport(dataset, title='Pandas Profiling Report')
# profile.to_widgets()

# %% [markdown]
# <a id="dataprep"></a>
# ## 4. Data Prep

# %% [markdown]
# ### Y and X split (target vs features)

# %%
X = dataset.drop(columns= ['MEDV'])
y = dataset['MEDV']

# %% [markdown]
# ### Scaling - so different scales don't affect the results

# %%
# Initialize min/max scaler: this takes data to a 0 to 1 scale
scaler = MinMaxScaler()

# %%
scaled_X = scaler.fit_transform(X)

# %% [markdown]
# ### Test/train split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <a id="modeling"></a>
# ## 5. Modeling

# %%
# Initialize decision tree (with default parameters)
dt_model = DecisionTreeRegressor(random_state=random_seed)

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1234)

# %%
# Show plot
tree.plot_tree(dt_model)
# Out:
# [Text(0.6765941484862943, 0.9761904761904762, 'X[5] <= 0.648\nsquared_error = 87.897\nsamples = 354\nvalue = 23.016'),
#  Text(0.4093558889226232, 0.9285714285714286, 'X[12] <= 0.35\nsquared_error = 41.295\nsamples = 292\nvalue = 20.084'),
#  Text(0.19535993884455238, 0.8809523809523809, 'X[7] <= 0.023\nsquared_error = 26.114\nsamples = 178\nvalue = 23.47'),
#  Text(0.12810656662040248, 0.8333333333333334, 'X[12] <= 0.242\nsquared_error = 91.577\nsamples = 4\nvalue = 44.475'),
#  Text(0.12533071651630812, 0.7857142857142857, 'squared_error = 0.0\nsamples = 3\nvalue = 50.0'),
#  Text(0.13088241672449688, 0.7857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.2626133110687023, 0.8333333333333334, 'X[5] <= 0.571\nsquared_error = 14.233\nsamples = 174\nvalue = 22.987'),
#  Text(0.13643411693268565, 0.7857142857142857, 'X[12] <= 0.166\nsquared_error = 7.174\nsamples = 133\nvalue = 21.639'),
#  Text(0.028452463566967384, 0.7380952380952381, 'X[0] <= 0.0\nsquared_error = 2.279\nsamples = 25\nvalue = 23.776'),
#  Text(0.025676613462873005, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.031228313671061762, 0.6904761904761905, 'X[3] <= 0.5\nsquared_error = 1.322\nsamples = 24\nvalue = 23.571'),
#  Text(0.028452463566967384, 0.6428571428571429, 'X[6] <= 0.228\nsquared_error = 0.846\nsamples = 23\nvalue = 23.422'),
#  Text(0.011103400416377515, 0.5952380952380952, 'X[1] <= 0.26\nsquared_error = 0.323\nsamples = 6\nvalue = 24.3'),
#  Text(0.005551700208188758, 0.5476190476190477, 'X[7] <= 0.351\nsquared_error = 0.112\nsamples = 4\nvalue = 24.65'),
#  Text(0.002775850104094379, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.008327550312283136, 0.5, 'X[0] <= 0.001\nsquared_error = 0.016\nsamples = 3\nvalue = 24.833'),
#  Text(0.005551700208188758, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.011103400416377515, 0.4523809523809524, 'X[10] <= 0.628\nsquared_error = 0.003\nsamples = 2\nvalue = 24.75'),
#  Text(0.008327550312283136, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.013879250520471894, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.016655100624566273, 0.5476190476190477, 'X[11] <= 0.972\nsquared_error = 0.01\nsamples = 2\nvalue = 23.6'),
#  Text(0.013879250520471894, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 23.7'),
#  Text(0.01943095072866065, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 23.5'),
#  Text(0.04580152671755725, 0.5952380952380952, 'X[7] <= 0.476\nsquared_error = 0.662\nsamples = 17\nvalue = 23.112'),
#  Text(0.033310201249132546, 0.5476190476190477, 'X[6] <= 0.552\nsquared_error = 0.595\nsamples = 10\nvalue = 23.49'),
#  Text(0.02498265093684941, 0.5, 'X[10] <= 0.42\nsquared_error = 0.339\nsamples = 6\nvalue = 23.05'),
#  Text(0.02220680083275503, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.027758501040943788, 0.4523809523809524, 'X[12] <= 0.12\nsquared_error = 0.142\nsamples = 5\nvalue = 22.84'),
#  Text(0.02498265093684941, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 22.1'),
#  Text(0.030534351145038167, 0.40476190476190477, 'X[7] <= 0.349\nsquared_error = 0.007\nsamples = 4\nvalue = 23.025'),
#  Text(0.027758501040943788, 0.35714285714285715, 'squared_error = 0.0\nsamples = 2\nvalue = 23.1'),
#  Text(0.033310201249132546, 0.35714285714285715, 'X[2] <= 0.207\nsquared_error = 0.003\nsamples = 2\nvalue = 22.95'),
#  Text(0.030534351145038167, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.03608605135322693, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.041637751561415685, 0.5, 'X[0] <= 0.015\nsquared_error = 0.252\nsamples = 4\nvalue = 24.15'),
#  Text(0.0388619014573213, 0.4523809523809524, 'X[0] <= 0.001\nsquared_error = 0.016\nsamples = 3\nvalue = 24.433'),
#  Text(0.03608605135322693, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.041637751561415685, 0.40476190476190477, 'X[4] <= 0.308\nsquared_error = 0.003\nsamples = 2\nvalue = 24.35'),
#  Text(0.0388619014573213, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.04441360166551006, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.04441360166551006, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.05829285218598196, 0.5476190476190477, 'X[6] <= 0.296\nsquared_error = 0.262\nsamples = 7\nvalue = 22.571'),
#  Text(0.0527411519777932, 0.5, 'X[10] <= 0.59\nsquared_error = 0.003\nsamples = 2\nvalue = 23.25'),
#  Text(0.04996530187369882, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.055517002081887576, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.06384455239417071, 0.5, 'X[9] <= 0.263\nsquared_error = 0.108\nsamples = 5\nvalue = 22.3'),
#  Text(0.061068702290076333, 0.4523809523809524, 'X[7] <= 0.649\nsquared_error = 0.023\nsamples = 4\nvalue = 22.15'),
#  Text(0.05829285218598196, 0.40476190476190477, 'X[9] <= 0.194\nsquared_error = 0.002\nsamples = 3\nvalue = 22.233'),
#  Text(0.055517002081887576, 0.35714285714285715, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.061068702290076333, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.06384455239417071, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.06662040249826509, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.034004163775156145, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.2444157702984039, 0.7380952380952381, 'X[10] <= 0.846\nsquared_error = 7.006\nsamples = 108\nvalue = 21.144'),
#  Text(0.18279406662040248, 0.6904761904761905, 'X[5] <= 0.482\nsquared_error = 6.506\nsamples = 95\nvalue = 21.445'),
#  Text(0.12235426786953504, 0.6428571428571429, 'X[11] <= 0.168\nsquared_error = 5.834\nsamples = 51\nvalue = 20.618'),
#  Text(0.11957841776544066, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.1251301179736294, 0.5952380952380952, 'X[4] <= 0.843\nsquared_error = 5.307\nsamples = 50\nvalue = 20.73'),
#  Text(0.10660999306037473, 0.5476190476190477, 'X[7] <= 0.256\nsquared_error = 4.869\nsamples = 48\nvalue = 20.867'),
#  Text(0.07789729354614851, 0.5, 'X[2] <= 0.101\nsquared_error = 4.673\nsamples = 27\nvalue = 21.519'),
#  Text(0.07512144344205413, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.08067314365024289, 0.4523809523809524, 'X[10] <= 0.532\nsquared_error = 3.901\nsamples = 26\nvalue = 21.331'),
#  Text(0.06939625260235947, 0.40476190476190477, 'X[6] <= 0.944\nsquared_error = 2.442\nsamples = 7\nvalue = 22.657'),
#  Text(0.06662040249826509, 0.35714285714285715, 'X[11] <= 0.971\nsquared_error = 0.389\nsamples = 6\nvalue = 23.25'),
#  Text(0.061068702290076333, 0.30952380952380953, 'X[2] <= 0.456\nsquared_error = 0.062\nsamples = 2\nvalue = 24.05'),
#  Text(0.05829285218598196, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.06384455239417071, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.07217210270645386, 0.30952380952380953, 'X[0] <= 0.001\nsquared_error = 0.072\nsamples = 4\nvalue = 22.85'),
#  Text(0.06939625260235947, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.07494795281054822, 0.2619047619047619, 'X[5] <= 0.411\nsquared_error = 0.007\nsamples = 3\nvalue = 22.7'),
#  Text(0.07217210270645386, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.0777238029146426, 0.21428571428571427, 'X[12] <= 0.246\nsquared_error = 0.002\nsamples = 2\nvalue = 22.65'),
#  Text(0.07494795281054822, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.08049965301873699, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.07217210270645386, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.0919500346981263, 0.40476190476190477, 'X[10] <= 0.628\nsquared_error = 3.552\nsamples = 19\nvalue = 20.842'),
#  Text(0.08049965301873699, 0.35714285714285715, 'X[7] <= 0.137\nsquared_error = 3.209\nsamples = 3\nvalue = 18.567'),
#  Text(0.0777238029146426, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.08327550312283137, 0.30952380952380953, 'X[2] <= 0.348\nsquared_error = 0.25\nsamples = 2\nvalue = 19.8'),
#  Text(0.08049965301873699, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.08605135322692574, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.10340041637751561, 0.35714285714285715, 'X[6] <= 0.339\nsquared_error = 2.463\nsamples = 16\nvalue = 21.269'),
#  Text(0.10062456627342123, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.10617626648161, 0.30952380952380953, 'X[7] <= 0.146\nsquared_error = 1.79\nsamples = 15\nvalue = 21.04'),
#  Text(0.0916030534351145, 0.2619047619047619, 'X[6] <= 0.526\nsquared_error = 1.937\nsamples = 8\nvalue = 21.738'),
#  Text(0.08882720333102012, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.09437890353920889, 0.21428571428571427, 'X[4] <= 0.489\nsquared_error = 0.968\nsamples = 7\nvalue = 21.343'),
#  Text(0.08743927827897294, 0.16666666666666666, 'X[6] <= 0.759\nsquared_error = 0.462\nsamples = 5\nvalue = 20.88'),
#  Text(0.08188757807078417, 0.11904761904761904, 'X[12] <= 0.329\nsquared_error = 0.16\nsamples = 2\nvalue = 21.6'),
#  Text(0.0791117279666898, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.08466342817487855, 0.07142857142857142, 'squared_error = -0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.09299097848716169, 0.11904761904761904, 'X[7] <= 0.082\nsquared_error = 0.087\nsamples = 3\nvalue = 20.4'),
#  Text(0.09021512838306732, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.09576682859125607, 0.07142857142857142, 'X[4] <= 0.432\nsquared_error = 0.01\nsamples = 2\nvalue = 20.2'),
#  Text(0.09299097848716169, 0.023809523809523808, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.09854267869535045, 0.023809523809523808, 'squared_error = -0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.10131852879944483, 0.16666666666666666, 'X[12] <= 0.329\nsquared_error = 0.36\nsamples = 2\nvalue = 22.5'),
#  Text(0.09854267869535045, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.1040943789035392, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.12074947952810548, 0.2619047619047619, 'X[6] <= 0.638\nsquared_error = 0.431\nsamples = 7\nvalue = 20.243'),
#  Text(0.1179736294240111, 0.21428571428571427, 'X[5] <= 0.438\nsquared_error = 0.152\nsamples = 6\nvalue = 20.467'),
#  Text(0.11242192921582235, 0.16666666666666666, 'X[7] <= 0.19\nsquared_error = 0.002\nsamples = 2\nvalue = 19.95'),
#  Text(0.10964607911172797, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.11519777931991672, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.12352532963219987, 0.16666666666666666, 'X[11] <= 0.993\nsquared_error = 0.027\nsamples = 4\nvalue = 20.725'),
#  Text(0.12074947952810548, 0.11904761904761904, 'X[2] <= 0.442\nsquared_error = 0.002\nsamples = 3\nvalue = 20.633'),
#  Text(0.1179736294240111, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.12352532963219987, 0.07142857142857142, 'squared_error = -0.0\nsamples = 2\nvalue = 20.6'),
#  Text(0.12630117973629423, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.12352532963219987, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.13532269257460097, 0.5, 'X[5] <= 0.42\nsquared_error = 3.872\nsamples = 21\nvalue = 20.029'),
#  Text(0.12074947952810548, 0.4523809523809524, 'X[9] <= 0.204\nsquared_error = 1.527\nsamples = 4\nvalue = 17.825'),
#  Text(0.11519777931991672, 0.40476190476190477, 'X[8] <= 0.196\nsquared_error = 0.09\nsamples = 2\nvalue = 19.0'),
#  Text(0.11242192921582235, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.1179736294240111, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.12630117973629423, 0.40476190476190477, 'X[11] <= 0.996\nsquared_error = 0.202\nsamples = 2\nvalue = 16.65'),
#  Text(0.12352532963219987, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 17.1'),
#  Text(0.12907702984038863, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 16.2'),
#  Text(0.14989590562109645, 0.4523809523809524, 'X[2] <= 0.182\nsquared_error = 3.012\nsamples = 17\nvalue = 20.547'),
#  Text(0.13740458015267176, 0.40476190476190477, 'X[5] <= 0.467\nsquared_error = 0.391\nsamples = 7\nvalue = 18.743'),
#  Text(0.13462873004857737, 0.35714285714285715, 'X[0] <= 0.001\nsquared_error = 0.156\nsamples = 6\nvalue = 18.95'),
#  Text(0.131852879944483, 0.30952380952380953, 'X[5] <= 0.444\nsquared_error = 0.086\nsamples = 5\nvalue = 18.82'),
#  Text(0.12907702984038863, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.13462873004857737, 0.2619047619047619, 'X[5] <= 0.463\nsquared_error = 0.035\nsamples = 4\nvalue = 18.7'),
#  Text(0.131852879944483, 0.21428571428571427, 'X[0] <= 0.0\nsquared_error = 0.007\nsamples = 3\nvalue = 18.6'),
#  Text(0.12907702984038863, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.13462873004857737, 0.16666666666666666, 'X[12] <= 0.188\nsquared_error = 0.003\nsamples = 2\nvalue = 18.65'),
#  Text(0.131852879944483, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.13740458015267176, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.13740458015267176, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 19.0'),
#  Text(0.13740458015267176, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.14018043025676613, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.16238723108952116, 0.40476190476190477, 'X[11] <= 0.997\nsquared_error = 0.973\nsamples = 10\nvalue = 21.81'),
#  Text(0.15405968077723803, 0.35714285714285715, 'X[7] <= 0.467\nsquared_error = 0.564\nsamples = 5\nvalue = 21.1'),
#  Text(0.15128383067314366, 0.30952380952380953, 'X[2] <= 0.309\nsquared_error = 0.093\nsamples = 4\nvalue = 21.45'),
#  Text(0.1457321304649549, 0.2619047619047619, 'X[5] <= 0.46\nsquared_error = 0.003\nsamples = 2\nvalue = 21.15'),
#  Text(0.14295628036086053, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 21.1'),
#  Text(0.14850798056904926, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.1568355308813324, 0.2619047619047619, 'X[11] <= 0.97\nsquared_error = 0.003\nsamples = 2\nvalue = 21.75'),
#  Text(0.15405968077723803, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.1596113809854268, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.1568355308813324, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.1707147814018043, 0.35714285714285715, 'X[4] <= 0.109\nsquared_error = 0.374\nsamples = 5\nvalue = 22.52'),
#  Text(0.16516308119361556, 0.30952380952380953, 'X[11] <= 0.999\nsquared_error = 0.022\nsamples = 2\nvalue = 21.85'),
#  Text(0.16238723108952116, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.16793893129770993, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.17626648160999306, 0.30952380952380953, 'X[1] <= 0.167\nsquared_error = 0.109\nsamples = 3\nvalue = 22.967'),
#  Text(0.1734906315058987, 0.2619047619047619, 'X[0] <= 0.001\nsquared_error = 0.022\nsamples = 2\nvalue = 22.75'),
#  Text(0.1707147814018043, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.17626648160999306, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.17904233171408743, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 23.4'),
#  Text(0.1436502428868841, 0.5476190476190477, 'X[0] <= 0.015\nsquared_error = 4.623\nsamples = 2\nvalue = 17.45'),
#  Text(0.14087439278278974, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 15.3'),
#  Text(0.14642609299097847, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.24323386537126995, 0.6428571428571429, 'X[9] <= 0.057\nsquared_error = 5.571\nsamples = 44\nvalue = 22.405'),
#  Text(0.24045801526717558, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.24600971547536432, 0.5952380952380952, 'X[5] <= 0.568\nsquared_error = 4.469\nsamples = 43\nvalue = 22.237'),
#  Text(0.24323386537126995, 0.5476190476190477, 'X[12] <= 0.228\nsquared_error = 3.773\nsamples = 42\nvalue = 22.374'),
#  Text(0.20610687022900764, 0.5, 'X[0] <= 0.001\nsquared_error = 4.656\nsamples = 16\nvalue = 23.425'),
#  Text(0.19292158223455932, 0.4523809523809524, 'X[12] <= 0.194\nsquared_error = 0.973\nsamples = 7\nvalue = 21.571'),
#  Text(0.1873698820263706, 0.40476190476190477, 'X[8] <= 0.109\nsquared_error = 0.137\nsamples = 4\nvalue = 22.275'),
#  Text(0.1845940319222762, 0.35714285714285715, 'X[11] <= 0.995\nsquared_error = 0.009\nsamples = 3\nvalue = 22.067'),
#  Text(0.18181818181818182, 0.30952380952380953, 'squared_error = 0.0\nsamples = 2\nvalue = 22.0'),
#  Text(0.1873698820263706, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.19014573213046496, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.1984732824427481, 0.40476190476190477, 'X[2] <= 0.216\nsquared_error = 0.549\nsamples = 3\nvalue = 20.633'),
#  Text(0.19569743233865372, 0.35714285714285715, 'X[4] <= 0.133\nsquared_error = 0.123\nsamples = 2\nvalue = 20.15'),
#  Text(0.19292158223455932, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.1984732824427481, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.20124913254684246, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.21929215822345594, 0.4523809523809524, 'X[11] <= 0.978\nsquared_error = 2.769\nsamples = 9\nvalue = 24.867'),
#  Text(0.21235253296322, 0.40476190476190477, 'X[6] <= 0.389\nsquared_error = 1.724\nsamples = 5\nvalue = 25.8'),
#  Text(0.20680083275503122, 0.35714285714285715, 'X[2] <= 0.289\nsquared_error = 0.723\nsamples = 2\nvalue = 27.25'),
#  Text(0.20402498265093685, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.20957668285912562, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 28.1'),
#  Text(0.21790423317140875, 0.35714285714285715, 'X[6] <= 0.676\nsquared_error = 0.056\nsamples = 3\nvalue = 24.833'),
#  Text(0.21512838306731435, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.22068008327550312, 0.30952380952380953, 'squared_error = 0.0\nsamples = 2\nvalue = 25.0'),
#  Text(0.22623178348369188, 0.40476190476190477, 'X[7] <= 0.225\nsquared_error = 1.625\nsamples = 4\nvalue = 23.7'),
#  Text(0.22345593337959752, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.22900763358778625, 0.35714285714285715, 'X[5] <= 0.497\nsquared_error = 0.207\nsamples = 3\nvalue = 24.4'),
#  Text(0.22623178348369188, 0.30952380952380953, 'X[9] <= 0.234\nsquared_error = 0.04\nsamples = 2\nvalue = 24.1'),
#  Text(0.22345593337959752, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.22900763358778625, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.23178348369188065, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.28036086051353226, 0.5, 'X[5] <= 0.528\nsquared_error = 2.131\nsamples = 26\nvalue = 21.727'),
#  Text(0.26162387231089523, 0.4523809523809524, 'X[5] <= 0.515\nsquared_error = 1.841\nsamples = 17\nvalue = 21.235'),
#  Text(0.25260235947258847, 0.40476190476190477, 'X[8] <= 0.283\nsquared_error = 1.187\nsamples = 14\nvalue = 21.65'),
#  Text(0.24288688410825815, 0.35714285714285715, 'X[1] <= 0.11\nsquared_error = 0.47\nsamples = 8\nvalue = 21.0'),
#  Text(0.23733518390006939, 0.30952380952380953, 'X[6] <= 0.498\nsquared_error = 0.166\nsamples = 5\nvalue = 21.46'),
#  Text(0.23455933379597502, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.24011103400416378, 0.2619047619047619, 'X[11] <= 0.989\nsquared_error = 0.037\nsamples = 4\nvalue = 21.275'),
#  Text(0.23455933379597502, 0.21428571428571427, 'X[4] <= 0.562\nsquared_error = 0.002\nsamples = 2\nvalue = 21.45'),
#  Text(0.23178348369188065, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.23733518390006939, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.24566273421235255, 0.21428571428571427, 'X[11] <= 0.995\nsquared_error = 0.01\nsamples = 2\nvalue = 21.1'),
#  Text(0.24288688410825815, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.24843858431644691, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.24843858431644691, 0.30952380952380953, 'X[4] <= 0.092\nsquared_error = 0.036\nsamples = 3\nvalue = 20.233'),
#  Text(0.24566273421235255, 0.2619047619047619, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.2512144344205413, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.2623178348369188, 0.35714285714285715, 'X[12] <= 0.308\nsquared_error = 0.828\nsamples = 6\nvalue = 22.517'),
#  Text(0.2595419847328244, 0.30952380952380953, 'X[2] <= 0.429\nsquared_error = 0.307\nsamples = 4\nvalue = 23.075'),
#  Text(0.25676613462873005, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 24.0'),
#  Text(0.2623178348369188, 0.2619047619047619, 'X[11] <= 0.998\nsquared_error = 0.029\nsamples = 3\nvalue = 22.767'),
#  Text(0.2595419847328244, 0.21428571428571427, 'X[6] <= 0.818\nsquared_error = 0.002\nsamples = 2\nvalue = 22.65'),
#  Text(0.25676613462873005, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.2623178348369188, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.2650936849410132, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.2650936849410132, 0.30952380952380953, 'squared_error = -0.0\nsamples = 2\nvalue = 21.4'),
#  Text(0.27064538514920194, 0.40476190476190477, 'X[2] <= 0.498\nsquared_error = 0.347\nsamples = 3\nvalue = 19.3'),
#  Text(0.2678695350451076, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.2734212352532963, 0.35714285714285715, 'X[6] <= 0.867\nsquared_error = 0.04\nsamples = 2\nvalue = 19.7'),
#  Text(0.27064538514920194, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.2761970853573907, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.29909784871616935, 0.4523809523809524, 'X[4] <= 0.564\nsquared_error = 1.36\nsamples = 9\nvalue = 22.656'),
#  Text(0.2914642609299098, 0.40476190476190477, 'X[5] <= 0.533\nsquared_error = 0.52\nsamples = 7\nvalue = 23.143'),
#  Text(0.28452463566967384, 0.35714285714285715, 'X[12] <= 0.257\nsquared_error = 0.09\nsamples = 2\nvalue = 24.1'),
#  Text(0.2817487855655795, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.2873004857737682, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.29840388619014574, 0.35714285714285715, 'X[11] <= 0.965\nsquared_error = 0.178\nsamples = 5\nvalue = 22.76'),
#  Text(0.29285218598195695, 0.30952380952380953, 'X[11] <= 0.885\nsquared_error = 0.002\nsamples = 2\nvalue = 22.25'),
#  Text(0.2900763358778626, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.29562803608605137, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.3039555863983345, 0.30952380952380953, 'X[7] <= 0.182\nsquared_error = 0.007\nsamples = 3\nvalue = 23.1'),
#  Text(0.3011797362942401, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.30673143650242884, 0.2619047619047619, 'X[6] <= 0.792\nsquared_error = 0.003\nsamples = 2\nvalue = 23.05'),
#  Text(0.3039555863983345, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.30950728660652327, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.30673143650242884, 0.40476190476190477, 'X[0] <= 0.054\nsquared_error = 0.563\nsamples = 2\nvalue = 20.95'),
#  Text(0.3039555863983345, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.30950728660652327, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 20.2'),
#  Text(0.24878556557945872, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.3060374739764053, 0.6904761904761905, 'X[12] <= 0.172\nsquared_error = 5.159\nsamples = 13\nvalue = 18.946'),
#  Text(0.30326162387231087, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.30881332408049966, 0.6428571428571429, 'X[11] <= 0.971\nsquared_error = 1.107\nsamples = 12\nvalue = 19.533'),
#  Text(0.3018736988202637, 0.5952380952380952, 'X[8] <= 0.152\nsquared_error = 0.036\nsamples = 3\nvalue = 18.333'),
#  Text(0.29909784871616935, 0.5476190476190477, 'squared_error = 0.0\nsamples = 2\nvalue = 18.2'),
#  Text(0.3046495489243581, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.3157529493407356, 0.5952380952380952, 'X[6] <= 0.859\nsquared_error = 0.824\nsamples = 9\nvalue = 19.933'),
#  Text(0.3102012491325468, 0.5476190476190477, 'X[5] <= 0.498\nsquared_error = 0.292\nsamples = 4\nvalue = 20.775'),
#  Text(0.30742539902845245, 0.5, 'X[4] <= 0.351\nsquared_error = 0.009\nsamples = 3\nvalue = 20.467'),
#  Text(0.3046495489243581, 0.4523809523809524, 'squared_error = 0.0\nsamples = 2\nvalue = 20.4'),
#  Text(0.3102012491325468, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.31297709923664124, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.32130464954892435, 0.5476190476190477, 'X[5] <= 0.56\nsquared_error = 0.23\nsamples = 5\nvalue = 19.26'),
#  Text(0.31852879944483, 0.5, 'X[12] <= 0.295\nsquared_error = 0.057\nsamples = 4\nvalue = 19.475'),
#  Text(0.3157529493407356, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.32130464954892435, 0.4523809523809524, 'X[7] <= 0.203\nsquared_error = 0.029\nsamples = 3\nvalue = 19.367'),
#  Text(0.31852879944483, 0.40476190476190477, 'X[6] <= 0.929\nsquared_error = 0.002\nsamples = 2\nvalue = 19.25'),
#  Text(0.3157529493407356, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.32130464954892435, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.3240804996530187, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.3240804996530187, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.3887925052047189, 0.7857142857142857, 'X[12] <= 0.112\nsquared_error = 12.125\nsamples = 41\nvalue = 27.359'),
#  Text(0.36224843858431643, 0.7380952380952381, 'X[10] <= 0.559\nsquared_error = 8.642\nsamples = 14\nvalue = 30.007'),
#  Text(0.35045107564191535, 0.6904761904761905, 'X[11] <= 0.991\nsquared_error = 2.728\nsamples = 10\nvalue = 31.48'),
#  Text(0.34073560027758504, 0.6428571428571429, 'X[5] <= 0.608\nsquared_error = 0.429\nsamples = 6\nvalue = 30.35'),
#  Text(0.33518390006939625, 0.5952380952380952, 'X[11] <= 0.977\nsquared_error = 0.082\nsamples = 3\nvalue = 29.767'),
#  Text(0.3324080499653019, 0.5476190476190477, 'X[4] <= 0.079\nsquared_error = 0.022\nsamples = 2\nvalue = 29.95'),
#  Text(0.3296321998612075, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 30.1'),
#  Text(0.33518390006939625, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.3379597501734906, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.3462873004857738, 0.5952380952380952, 'X[9] <= 0.376\nsquared_error = 0.096\nsamples = 3\nvalue = 30.933'),
#  Text(0.3435114503816794, 0.5476190476190477, 'X[1] <= 0.575\nsquared_error = 0.002\nsamples = 2\nvalue = 31.15'),
#  Text(0.34073560027758504, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.3462873004857738, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 31.1'),
#  Text(0.34906315058986814, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 30.5'),
#  Text(0.36016655100624567, 0.6428571428571429, 'X[0] <= 0.002\nsquared_error = 1.387\nsamples = 4\nvalue = 33.175'),
#  Text(0.3573907009021513, 0.5952380952380952, 'X[11] <= 0.996\nsquared_error = 0.202\nsamples = 3\nvalue = 32.533'),
#  Text(0.3546148507980569, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.36016655100624567, 0.5476190476190477, 'X[9] <= 0.07\nsquared_error = 0.062\nsamples = 2\nvalue = 32.25'),
#  Text(0.3573907009021513, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 32.5'),
#  Text(0.36294240111034004, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.36294240111034004, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 35.1'),
#  Text(0.37404580152671757, 0.6904761904761905, 'X[6] <= 0.567\nsquared_error = 4.447\nsamples = 4\nvalue = 26.325'),
#  Text(0.3712699514226232, 0.6428571428571429, 'X[2] <= 0.201\nsquared_error = 0.407\nsamples = 3\nvalue = 27.5'),
#  Text(0.3684941013185288, 0.5952380952380952, 'X[10] <= 0.691\nsquared_error = 0.002\nsamples = 2\nvalue = 27.95'),
#  Text(0.3657182512144344, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(0.3712699514226232, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.37404580152671757, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.37682165163081194, 0.6428571428571429, 'squared_error = -0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.41533657182512146, 0.7380952380952381, 'X[7] <= 0.258\nsquared_error = 8.407\nsamples = 27\nvalue = 25.985'),
#  Text(0.3948646773074254, 0.6904761904761905, 'X[2] <= 0.321\nsquared_error = 9.042\nsamples = 12\nvalue = 27.6'),
#  Text(0.3851492019430951, 0.6428571428571429, 'X[12] <= 0.18\nsquared_error = 2.125\nsamples = 8\nvalue = 29.237'),
#  Text(0.3795975017349063, 0.5952380952380952, 'X[4] <= 0.115\nsquared_error = 1.308\nsamples = 5\nvalue = 30.1'),
#  Text(0.37682165163081194, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.3823733518390007, 0.5476190476190477, 'X[7] <= 0.205\nsquared_error = 0.507\nsamples = 4\nvalue = 29.625'),
#  Text(0.3795975017349063, 0.5, 'X[5] <= 0.63\nsquared_error = 0.009\nsamples = 3\nvalue = 30.033'),
#  Text(0.37682165163081194, 0.4523809523809524, 'X[11] <= 0.994\nsquared_error = 0.0\nsamples = 2\nvalue = 30.1'),
#  Text(0.37404580152671757, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 30.1'),
#  Text(0.3795975017349063, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 30.1'),
#  Text(0.3823733518390007, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 29.9'),
#  Text(0.3851492019430951, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.39070090215128384, 0.5952380952380952, 'X[6] <= 0.669\nsquared_error = 0.18\nsamples = 3\nvalue = 27.8'),
#  Text(0.38792505204718947, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.3934767522553782, 0.5476190476190477, 'squared_error = -0.0\nsamples = 2\nvalue = 27.5'),
#  Text(0.40458015267175573, 0.6428571428571429, 'X[2] <= 0.456\nsquared_error = 6.787\nsamples = 4\nvalue = 24.325'),
#  Text(0.40180430256766136, 0.5952380952380952, 'X[5] <= 0.59\nsquared_error = 0.542\nsamples = 3\nvalue = 22.867'),
#  Text(0.39902845246356694, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.40458015267175573, 0.5476190476190477, 'X[7] <= 0.128\nsquared_error = 0.16\nsamples = 2\nvalue = 22.4'),
#  Text(0.40180430256766136, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.4073560027758501, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.4073560027758501, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.4358084663428175, 0.6904761904761905, 'X[12] <= 0.241\nsquared_error = 4.145\nsamples = 15\nvalue = 24.693'),
#  Text(0.4253990284524636, 0.6428571428571429, 'X[1] <= 0.235\nsquared_error = 2.934\nsamples = 13\nvalue = 25.185'),
#  Text(0.41290770298403884, 0.5952380952380952, 'X[12] <= 0.129\nsquared_error = 1.318\nsamples = 5\nvalue = 26.72'),
#  Text(0.41013185287994447, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 28.6'),
#  Text(0.41568355308813326, 0.5476190476190477, 'X[7] <= 0.288\nsquared_error = 0.543\nsamples = 4\nvalue = 26.25'),
#  Text(0.41290770298403884, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 25.1'),
#  Text(0.41845940319222763, 0.5, 'X[0] <= 0.001\nsquared_error = 0.136\nsamples = 3\nvalue = 26.633'),
#  Text(0.41568355308813326, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.421235253296322, 0.4523809523809524, 'X[7] <= 0.455\nsquared_error = 0.04\nsamples = 2\nvalue = 26.4'),
#  Text(0.41845940319222763, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.42401110340041637, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 26.2'),
#  Text(0.43789035392088826, 0.5952380952380952, 'X[7] <= 0.511\nsquared_error = 1.549\nsamples = 8\nvalue = 24.225'),
#  Text(0.4323386537126995, 0.5476190476190477, 'X[12] <= 0.185\nsquared_error = 0.602\nsamples = 4\nvalue = 23.275'),
#  Text(0.42956280360860516, 0.5, 'X[5] <= 0.585\nsquared_error = 0.08\nsamples = 3\nvalue = 23.7'),
#  Text(0.42678695350451074, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.4323386537126995, 0.4523809523809524, 'X[12] <= 0.151\nsquared_error = 0.0\nsamples = 2\nvalue = 23.9'),
#  Text(0.42956280360860516, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.4351145038167939, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.4351145038167939, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.44344205412907706, 0.5476190476190477, 'X[8] <= 0.065\nsquared_error = 0.692\nsamples = 4\nvalue = 25.175'),
#  Text(0.44066620402498263, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.4462179042331714, 0.5, 'X[10] <= 0.447\nsquared_error = 0.02\nsamples = 3\nvalue = 24.7'),
#  Text(0.44344205412907706, 0.4523809523809524, 'X[6] <= 0.332\nsquared_error = 0.0\nsamples = 2\nvalue = 24.8'),
#  Text(0.44066620402498263, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.4462179042331714, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.4489937543372658, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.4462179042331714, 0.6428571428571429, 'X[7] <= 0.378\nsquared_error = 0.25\nsamples = 2\nvalue = 21.5'),
#  Text(0.44344205412907706, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.4489937543372658, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.6233518390006939, 0.8809523809523809, 'X[7] <= 0.086\nsquared_error = 19.151\nsamples = 114\nvalue = 14.797'),
#  Text(0.5292765440666204, 0.8333333333333334, 'X[0] <= 0.077\nsquared_error = 12.162\nsamples = 62\nvalue = 12.266'),
#  Text(0.47848716169326855, 0.7857142857142857, 'X[5] <= 0.358\nsquared_error = 6.82\nsamples = 22\nvalue = 15.041'),
#  Text(0.4600971547536433, 0.7380952380952381, 'X[0] <= 0.01\nsquared_error = 4.836\nsamples = 6\nvalue = 12.567'),
#  Text(0.4573213046495489, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 8.1'),
#  Text(0.4628730048577377, 0.6904761904761905, 'X[0] <= 0.027\nsquared_error = 1.014\nsamples = 5\nvalue = 13.46'),
#  Text(0.4573213046495489, 0.6428571428571429, 'X[8] <= 0.152\nsquared_error = 0.01\nsamples = 2\nvalue = 14.5'),
#  Text(0.45454545454545453, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 14.4'),
#  Text(0.4600971547536433, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.46842470506592643, 0.6428571428571429, 'X[12] <= 0.726\nsquared_error = 0.482\nsamples = 3\nvalue = 12.767'),
#  Text(0.46564885496183206, 0.5952380952380952, 'X[0] <= 0.032\nsquared_error = 0.023\nsamples = 2\nvalue = 13.25'),
#  Text(0.4628730048577377, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.46842470506592643, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 13.4'),
#  Text(0.4712005551700208, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.49687716863289383, 0.7380952380952381, 'X[6] <= 0.884\nsquared_error = 4.407\nsamples = 16\nvalue = 15.969'),
#  Text(0.49410131852879946, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.4996530187369882, 0.6904761904761905, 'X[12] <= 0.435\nsquared_error = 2.603\nsamples = 15\nvalue = 15.607'),
#  Text(0.4823039555863983, 0.6428571428571429, 'X[5] <= 0.419\nsquared_error = 0.72\nsamples = 5\nvalue = 16.8'),
#  Text(0.4767522553782096, 0.5952380952380952, 'X[8] <= 0.152\nsquared_error = 0.09\nsamples = 2\nvalue = 15.9'),
#  Text(0.4739764052741152, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 16.2'),
#  Text(0.47952810548230396, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.4878556557945871, 0.5952380952380952, 'X[6] <= 0.91\nsquared_error = 0.24\nsamples = 3\nvalue = 17.4'),
#  Text(0.4850798056904927, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 16.8'),
#  Text(0.4906315058986815, 0.5476190476190477, 'X[5] <= 0.503\nsquared_error = 0.09\nsamples = 2\nvalue = 17.7'),
#  Text(0.4878556557945871, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.49340735600277585, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.5170020818875781, 0.6428571428571429, 'X[5] <= 0.539\nsquared_error = 2.477\nsamples = 10\nvalue = 15.01'),
#  Text(0.5142262317834837, 0.5952380952380952, 'X[6] <= 0.98\nsquared_error = 1.974\nsamples = 9\nvalue = 15.289'),
#  Text(0.5045107564191533, 0.5476190476190477, 'X[6] <= 0.966\nsquared_error = 1.638\nsamples = 6\nvalue = 15.817'),
#  Text(0.4989590562109646, 0.5, 'X[11] <= 0.998\nsquared_error = 0.172\nsamples = 4\nvalue = 14.95'),
#  Text(0.4961832061068702, 0.4523809523809524, 'X[2] <= 0.674\nsquared_error = 0.042\nsamples = 3\nvalue = 15.167'),
#  Text(0.49340735600277585, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 14.9'),
#  Text(0.4989590562109646, 0.40476190476190477, 'X[7] <= 0.049\nsquared_error = 0.01\nsamples = 2\nvalue = 15.3'),
#  Text(0.4961832061068702, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.501734906315059, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.501734906315059, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 14.3'),
#  Text(0.5100624566273422, 0.5, 'X[9] <= 0.24\nsquared_error = 0.063\nsamples = 2\nvalue = 17.55'),
#  Text(0.5072866065232478, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.5128383067314365, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.5239417071478141, 0.5476190476190477, 'X[0] <= 0.036\nsquared_error = 0.976\nsamples = 3\nvalue = 14.233'),
#  Text(0.5211658570437196, 0.5, 'X[6] <= 0.991\nsquared_error = 0.062\nsamples = 2\nvalue = 13.55'),
#  Text(0.5183900069396252, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 13.3'),
#  Text(0.5239417071478141, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.5267175572519084, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.5197779319916724, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 12.5'),
#  Text(0.5800659264399722, 0.7857142857142857, 'X[4] <= 0.597\nsquared_error = 8.536\nsamples = 40\nvalue = 10.74'),
#  Text(0.5572519083969466, 0.7380952380952381, 'X[0] <= 0.294\nsquared_error = 3.082\nsamples = 11\nvalue = 12.973'),
#  Text(0.5544760582928522, 0.6904761904761905, 'X[5] <= 0.522\nsquared_error = 2.172\nsamples = 10\nvalue = 12.64'),
#  Text(0.5433726578764747, 0.6428571428571429, 'X[11] <= 0.996\nsquared_error = 2.172\nsamples = 6\nvalue = 11.933'),
#  Text(0.5378209576682859, 0.5952380952380952, 'X[5] <= 0.41\nsquared_error = 0.645\nsamples = 4\nvalue = 11.0'),
#  Text(0.5350451075641915, 0.5476190476190477, 'X[4] <= 0.487\nsquared_error = 0.01\nsamples = 2\nvalue = 11.8'),
#  Text(0.5322692574600971, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.5378209576682859, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.5405968077723803, 0.5476190476190477, 'squared_error = -0.0\nsamples = 2\nvalue = 10.2'),
#  Text(0.5489243580846634, 0.5952380952380952, 'X[0] <= 0.166\nsquared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.546148507980569, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.5517002081887578, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.5655794587092297, 0.6428571428571429, 'X[11] <= 0.957\nsquared_error = 0.3\nsamples = 4\nvalue = 13.7'),
#  Text(0.5600277585010409, 0.5952380952380952, 'X[11] <= 0.562\nsquared_error = 0.09\nsamples = 2\nvalue = 14.2'),
#  Text(0.5572519083969466, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 14.5'),
#  Text(0.5628036086051353, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.5711311589174185, 0.5952380952380952, 'X[0] <= 0.188\nsquared_error = 0.01\nsamples = 2\nvalue = 13.2'),
#  Text(0.5683553088133241, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.3'),
#  Text(0.5739070090215128, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.5600277585010409, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 16.3'),
#  Text(0.6028799444829979, 0.7380952380952381, 'X[12] <= 0.485\nsquared_error = 7.997\nsamples = 29\nvalue = 9.893'),
#  Text(0.5850104094378904, 0.6904761904761905, 'X[5] <= 0.526\nsquared_error = 4.108\nsamples = 5\nvalue = 13.9'),
#  Text(0.5794587092297016, 0.6428571428571429, 'X[6] <= 0.852\nsquared_error = 1.429\nsamples = 3\nvalue = 12.467'),
#  Text(0.5766828591256072, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.582234559333796, 0.5952380952380952, 'X[6] <= 0.935\nsquared_error = 0.302\nsamples = 2\nvalue = 13.25'),
#  Text(0.5794587092297016, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.5850104094378904, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 12.7'),
#  Text(0.5905621096460791, 0.6428571428571429, 'X[0] <= 0.118\nsquared_error = 0.423\nsamples = 2\nvalue = 16.05'),
#  Text(0.5877862595419847, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.5933379597501734, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6207494795281054, 0.6904761904761905, 'X[0] <= 0.11\nsquared_error = 4.765\nsamples = 24\nvalue = 9.058'),
#  Text(0.6016655100624566, 0.6428571428571429, 'X[12] <= 0.507\nsquared_error = 1.857\nsamples = 8\nvalue = 11.125'),
#  Text(0.5988896599583623, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.604441360166551, 0.5952380952380952, 'X[11] <= 0.198\nsquared_error = 0.997\nsamples = 7\nvalue = 11.5'),
#  Text(0.6016655100624566, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 9.5'),
#  Text(0.6072172102706453, 0.5476190476190477, 'X[0] <= 0.104\nsquared_error = 0.386\nsamples = 6\nvalue = 11.833'),
#  Text(0.6016655100624566, 0.5, 'X[12] <= 0.617\nsquared_error = 0.232\nsamples = 4\nvalue = 11.525'),
#  Text(0.5988896599583623, 0.4523809523809524, 'X[5] <= 0.441\nsquared_error = 0.042\nsamples = 3\nvalue = 11.267'),
#  Text(0.5961138098542679, 0.40476190476190477, 'X[5] <= 0.364\nsquared_error = 0.01\nsamples = 2\nvalue = 11.4'),
#  Text(0.5933379597501734, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 11.5'),
#  Text(0.5988896599583623, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.6016655100624566, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.604441360166551, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.6127689104788342, 0.5, 'X[0] <= 0.107\nsquared_error = 0.123\nsamples = 2\nvalue = 12.45'),
#  Text(0.6099930603747398, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 12.8'),
#  Text(0.6155447605829285, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.6398334489937544, 0.6428571428571429, 'X[4] <= 0.641\nsquared_error = 3.016\nsamples = 16\nvalue = 8.025'),
#  Text(0.6266481609993061, 0.5952380952380952, 'X[0] <= 0.28\nsquared_error = 1.264\nsamples = 8\nvalue = 6.925'),
#  Text(0.6210964607911172, 0.5476190476190477, 'X[6] <= 0.838\nsquared_error = 0.482\nsamples = 6\nvalue = 7.467'),
#  Text(0.6183206106870229, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.6238723108952117, 0.5, 'X[5] <= 0.49\nsquared_error = 0.252\nsamples = 5\nvalue = 7.7'),
#  Text(0.6210964607911172, 0.4523809523809524, 'squared_error = 0.0\nsamples = 2\nvalue = 8.3'),
#  Text(0.6266481609993061, 0.4523809523809524, 'X[5] <= 0.584\nsquared_error = 0.02\nsamples = 3\nvalue = 7.3'),
#  Text(0.6238723108952117, 0.40476190476190477, 'X[11] <= 0.534\nsquared_error = 0.0\nsamples = 2\nvalue = 7.2'),
#  Text(0.6210964607911172, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.6266481609993061, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.6294240111034004, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.6321998612074948, 0.5476190476190477, 'X[7] <= 0.034\nsquared_error = 0.09\nsamples = 2\nvalue = 5.3'),
#  Text(0.6294240111034004, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.6349757113115891, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.6530187369882027, 0.5952380952380952, 'X[12] <= 0.765\nsquared_error = 2.347\nsamples = 8\nvalue = 9.125'),
#  Text(0.6433032616238723, 0.5476190476190477, 'X[6] <= 0.84\nsquared_error = 1.485\nsamples = 4\nvalue = 10.3'),
#  Text(0.6405274115197779, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 8.4'),
#  Text(0.6460791117279667, 0.5, 'X[5] <= 0.494\nsquared_error = 0.376\nsamples = 3\nvalue = 10.933'),
#  Text(0.6433032616238723, 0.4523809523809524, 'X[12] <= 0.647\nsquared_error = 0.0\nsamples = 2\nvalue = 10.5'),
#  Text(0.6405274115197779, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.6460791117279667, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.648854961832061, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.6627342123525329, 0.5476190476190477, 'X[11] <= 0.86\nsquared_error = 0.448\nsamples = 4\nvalue = 7.95'),
#  Text(0.6571825121443442, 0.5, 'X[4] <= 0.689\nsquared_error = 0.04\nsamples = 2\nvalue = 8.6'),
#  Text(0.6544066620402498, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.6599583622484386, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 8.4'),
#  Text(0.6682859125607217, 0.5, 'X[0] <= 0.221\nsquared_error = 0.01\nsamples = 2\nvalue = 7.3'),
#  Text(0.6655100624566274, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.6710617626648161, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 7.4'),
#  Text(0.7174271339347675, 0.8333333333333334, 'X[11] <= 0.812\nsquared_error = 10.738\nsamples = 52\nvalue = 17.815'),
# ...
#  Text(0.7529493407356003, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.7612768910478834, 0.5476190476190477, 'X[9] <= 0.569\nsquared_error = 0.01\nsamples = 2\nvalue = 19.9'),
#  Text(0.758501040943789, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.7640527411519777, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.7874739764052742, 0.7380952380952381, 'X[0] <= 0.002\nsquared_error = 8.277\nsamples = 22\nvalue = 17.818'),
#  Text(0.7751561415683553, 0.6904761904761905, 'X[12] <= 0.474\nsquared_error = 9.354\nsamples = 5\nvalue = 21.08'),
#  Text(0.7723802914642609, 0.6428571428571429, 'X[4] <= 0.368\nsquared_error = 0.367\nsamples = 4\nvalue = 19.575'),
#  Text(0.7696044413601666, 0.5952380952380952, 'X[0] <= 0.001\nsquared_error = 0.109\nsamples = 3\nvalue = 19.267'),
#  Text(0.7668285912560722, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.7723802914642609, 0.5476190476190477, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.7751561415683553, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.7779319916724496, 0.6428571428571429, 'squared_error = -0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.7997918112421929, 0.6904761904761905, 'X[6] <= 0.921\nsquared_error = 3.911\nsamples = 17\nvalue = 16.859'),
#  Text(0.7862595419847328, 0.6428571428571429, 'X[6] <= 0.905\nsquared_error = 3.145\nsamples = 6\nvalue = 18.383'),
#  Text(0.7807078417765441, 0.5952380952380952, 'X[2] <= 0.316\nsquared_error = 0.535\nsamples = 4\nvalue = 17.3'),
#  Text(0.7779319916724496, 0.5476190476190477, 'squared_error = 0.0\nsamples = 2\nvalue = 16.6'),
#  Text(0.7834836918806385, 0.5476190476190477, 'X[9] <= 0.691\nsquared_error = 0.09\nsamples = 2\nvalue = 18.0'),
#  Text(0.7807078417765441, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.7862595419847328, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 17.7'),
#  Text(0.7918112421929215, 0.5952380952380952, 'X[11] <= 0.991\nsquared_error = 1.322\nsamples = 2\nvalue = 20.55'),
#  Text(0.7890353920888272, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.794587092297016, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.813324080499653, 0.6428571428571429, 'X[12] <= 0.44\nsquared_error = 2.369\nsamples = 11\nvalue = 16.027'),
#  Text(0.8029146426092991, 0.5952380952380952, 'X[4] <= 0.316\nsquared_error = 0.872\nsamples = 4\nvalue = 17.575'),
#  Text(0.8001387925052047, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(0.8056904927133934, 0.5476190476190477, 'X[4] <= 0.642\nsquared_error = 0.06\nsamples = 3\nvalue = 18.1'),
#  Text(0.8029146426092991, 0.5, 'X[7] <= 0.106\nsquared_error = 0.023\nsamples = 2\nvalue = 18.25'),
#  Text(0.8001387925052047, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.8056904927133934, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.8084663428174879, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.823733518390007, 0.5952380952380952, 'X[5] <= 0.391\nsquared_error = 1.074\nsamples = 7\nvalue = 15.143'),
#  Text(0.816793893129771, 0.5476190476190477, 'X[7] <= 0.337\nsquared_error = 0.16\nsamples = 2\nvalue = 14.0'),
#  Text(0.8140180430256766, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 13.6'),
#  Text(0.8195697432338653, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 14.4'),
#  Text(0.8306731436502429, 0.5476190476190477, 'X[0] <= 0.058\nsquared_error = 0.708\nsamples = 5\nvalue = 15.6'),
#  Text(0.8251214434420542, 0.5, 'X[7] <= 0.462\nsquared_error = 0.576\nsamples = 3\nvalue = 16.067'),
#  Text(0.8223455933379598, 0.4523809523809524, 'X[2] <= 0.459\nsquared_error = 0.01\nsamples = 2\nvalue = 16.6'),
#  Text(0.8195697432338653, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.8251214434420542, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.8278972935461485, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.8362248438584317, 0.5, 'X[11] <= 0.926\nsquared_error = 0.09\nsamples = 2\nvalue = 14.9'),
#  Text(0.8334489937543372, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.8390006939625261, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.9438324080499653, 0.9285714285714286, 'X[5] <= 0.743\nsquared_error = 76.221\nsamples = 62\nvalue = 36.824'),
#  Text(0.9152498265093685, 0.8809523809523809, 'X[12] <= 0.387\nsquared_error = 39.454\nsamples = 39\nvalue = 32.241'),
#  Text(0.9051006245662734, 0.8333333333333334, 'X[7] <= 0.069\nsquared_error = 22.096\nsamples = 37\nvalue = 33.222'),
#  Text(0.8931297709923665, 0.7857142857142857, 'X[0] <= 0.044\nsquared_error = 18.923\nsamples = 2\nvalue = 45.65'),
#  Text(0.890353920888272, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 41.3'),
#  Text(0.8959056210964608, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9170714781401804, 0.7857142857142857, 'X[10] <= 0.755\nsquared_error = 12.947\nsamples = 35\nvalue = 32.511'),
#  Text(0.9014573213046495, 0.7380952380952381, 'X[4] <= 0.213\nsquared_error = 9.536\nsamples = 33\nvalue = 33.0'),
#  Text(0.878556557945871, 0.6904761904761905, 'X[7] <= 0.512\nsquared_error = 5.042\nsamples = 23\nvalue = 33.861'),
#  Text(0.8625954198473282, 0.6428571428571429, 'X[5] <= 0.707\nsquared_error = 2.603\nsamples = 13\nvalue = 35.1'),
#  Text(0.8570437196391395, 0.5952380952380952, 'X[0] <= 0.001\nsquared_error = 2.07\nsamples = 10\nvalue = 35.65'),
#  Text(0.8542678695350451, 0.5476190476190477, 'X[0] <= 0.0\nsquared_error = 1.498\nsamples = 9\nvalue = 35.933'),
#  Text(0.8473282442748091, 0.5, 'X[5] <= 0.661\nsquared_error = 0.562\nsamples = 2\nvalue = 34.15'),
#  Text(0.8445523941707148, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.8501040943789036, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.861207494795281, 0.5, 'X[12] <= 0.096\nsquared_error = 0.597\nsamples = 7\nvalue = 36.443'),
#  Text(0.8556557945870923, 0.4523809523809524, 'X[5] <= 0.69\nsquared_error = 0.122\nsamples = 4\nvalue = 36.975'),
#  Text(0.8528799444829979, 0.40476190476190477, 'X[6] <= 0.223\nsquared_error = 0.016\nsamples = 3\nvalue = 37.167'),
#  Text(0.8501040943789036, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 37.0'),
#  Text(0.8556557945870923, 0.35714285714285715, 'X[6] <= 0.413\nsquared_error = 0.003\nsamples = 2\nvalue = 37.25'),
#  Text(0.8528799444829979, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 37.3'),
#  Text(0.8584316446911867, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 37.2'),
#  Text(0.8584316446911867, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 36.4'),
#  Text(0.8667591950034698, 0.4523809523809524, 'X[0] <= 0.001\nsquared_error = 0.349\nsamples = 3\nvalue = 35.733'),
#  Text(0.8639833448993754, 0.40476190476190477, 'X[1] <= 0.165\nsquared_error = 0.002\nsamples = 2\nvalue = 36.15'),
#  Text(0.861207494795281, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 36.2'),
#  Text(0.8667591950034698, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 36.1'),
#  Text(0.8695350451075642, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8598195697432338, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.868147120055517, 0.5952380952380952, 'X[4] <= 0.153\nsquared_error = 0.009\nsamples = 3\nvalue = 33.267'),
#  Text(0.8653712699514227, 0.5476190476190477, 'squared_error = 0.0\nsamples = 2\nvalue = 33.2'),
#  Text(0.8709229701596114, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.8945176960444136, 0.6428571428571429, 'X[0] <= 0.0\nsquared_error = 3.623\nsamples = 10\nvalue = 32.25'),
#  Text(0.8861901457321305, 0.5952380952380952, 'X[0] <= 0.0\nsquared_error = 0.862\nsamples = 7\nvalue = 33.371'),
#  Text(0.8778625954198473, 0.5476190476190477, 'X[0] <= 0.0\nsquared_error = 0.095\nsamples = 4\nvalue = 32.7'),
#  Text(0.8750867453157529, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 32.2'),
#  Text(0.8806384455239417, 0.5, 'X[2] <= 0.038\nsquared_error = 0.016\nsamples = 3\nvalue = 32.867'),
#  Text(0.8778625954198473, 0.4523809523809524, 'X[5] <= 0.682\nsquared_error = 0.003\nsamples = 2\nvalue = 32.95'),
#  Text(0.8750867453157529, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 33.0'),
#  Text(0.8806384455239417, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 32.9'),
#  Text(0.8834142956280361, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 32.7'),
#  Text(0.8945176960444136, 0.5476190476190477, 'X[0] <= 0.0\nsquared_error = 0.482\nsamples = 3\nvalue = 34.267'),
#  Text(0.8917418459403192, 0.5, 'X[4] <= 0.038\nsquared_error = 0.022\nsamples = 2\nvalue = 34.75'),
#  Text(0.8889659958362248, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8945176960444136, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 34.6'),
#  Text(0.897293546148508, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 33.3'),
#  Text(0.9028452463566967, 0.5952380952380952, 'X[9] <= 0.272\nsquared_error = 0.282\nsamples = 3\nvalue = 29.633'),
#  Text(0.9000693962526024, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 30.3'),
#  Text(0.9056210964607911, 0.5476190476190477, 'X[6] <= 0.057\nsquared_error = 0.09\nsamples = 2\nvalue = 29.3'),
#  Text(0.9028452463566967, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.9083969465648855, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.9243580846634282, 0.6904761904761905, 'X[0] <= 0.005\nsquared_error = 14.246\nsamples = 10\nvalue = 31.02'),
#  Text(0.9167244968771686, 0.6428571428571429, 'X[7] <= 0.208\nsquared_error = 4.402\nsamples = 3\nvalue = 26.333'),
#  Text(0.9139486467730743, 0.5952380952380952, 'X[10] <= 0.532\nsquared_error = 1.0\nsamples = 2\nvalue = 27.7'),
#  Text(0.9111727966689799, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.9167244968771686, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.919500346981263, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.9319916724496877, 0.6428571428571429, 'X[7] <= 0.08\nsquared_error = 5.016\nsamples = 7\nvalue = 33.029'),
#  Text(0.9250520471894518, 0.5952380952380952, 'X[12] <= 0.171\nsquared_error = 0.062\nsamples = 2\nvalue = 36.25'),
#  Text(0.9222761970853574, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 36.0'),
#  Text(0.9278278972935462, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 36.5'),
#  Text(0.9389312977099237, 0.5952380952380952, 'X[12] <= 0.24\nsquared_error = 1.186\nsamples = 5\nvalue = 31.74'),
#  Text(0.9333795975017349, 0.5476190476190477, 'X[11] <= 0.986\nsquared_error = 1.082\nsamples = 3\nvalue = 32.333'),
#  Text(0.9306037473976405, 0.5, 'X[11] <= 0.965\nsquared_error = 0.01\nsamples = 2\nvalue = 31.6'),
#  Text(0.9278278972935462, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 31.7'),
#  Text(0.9333795975017349, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.9361554476058292, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 33.8'),
#  Text(0.9444829979181124, 0.5476190476190477, 'X[0] <= 0.009\nsquared_error = 0.022\nsamples = 2\nvalue = 30.85'),
#  Text(0.9417071478140181, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.9472588480222068, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 31.0'),
#  Text(0.9326856349757113, 0.7380952380952381, 'X[2] <= 0.534\nsquared_error = 0.302\nsamples = 2\nvalue = 24.45'),
#  Text(0.9299097848716169, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.9354614850798056, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.9253990284524636, 0.8333333333333334, 'X[5] <= 0.694\nsquared_error = 13.69\nsamples = 2\nvalue = 14.1'),
#  Text(0.9226231783483692, 0.7857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.9281748785565579, 0.7857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.9724149895905622, 0.8809523809523809, 'X[9] <= 0.663\nsquared_error = 42.551\nsamples = 23\nvalue = 44.596'),
#  Text(0.9696391394864677, 0.8333333333333334, 'X[7] <= 0.189\nsquared_error = 20.007\nsamples = 22\nvalue = 45.627'),
#  Text(0.9528105482303956, 0.7857142857142857, 'X[0] <= 0.006\nsquared_error = 5.84\nsamples = 10\nvalue = 48.67'),
#  Text(0.9500346981263011, 0.7380952380952381, 'X[12] <= 0.134\nsquared_error = 7.967\nsamples = 4\nvalue = 46.675'),
#  Text(0.9472588480222068, 0.6904761904761905, 'X[12] <= 0.071\nsquared_error = 4.942\nsamples = 3\nvalue = 47.867'),
#  Text(0.9444829979181124, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 44.8'),
#  Text(0.9500346981263011, 0.6428571428571429, 'X[0] <= 0.003\nsquared_error = 0.36\nsamples = 2\nvalue = 49.4'),
#  Text(0.9472588480222068, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9528105482303956, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 48.8'),
#  Text(0.9528105482303956, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 43.1'),
#  Text(0.9555863983344899, 0.7380952380952381, 'squared_error = -0.0\nsamples = 6\nvalue = 50.0'),
#  Text(0.9864677307425399, 0.7857142857142857, 'X[12] <= 0.065\nsquared_error = 17.669\nsamples = 12\nvalue = 43.092'),
#  Text(0.9784871616932685, 0.7380952380952381, 'X[0] <= 0.004\nsquared_error = 11.538\nsamples = 10\nvalue = 44.32'),
#  Text(0.970853573907009, 0.6904761904761905, 'X[5] <= 0.826\nsquared_error = 6.313\nsamples = 7\nvalue = 45.871'),
#  Text(0.963913948646773, 0.6428571428571429, 'X[8] <= 0.13\nsquared_error = 2.53\nsamples = 5\nvalue = 44.56'),
#  Text(0.9583622484385843, 0.5952380952380952, 'X[11] <= 0.994\nsquared_error = 0.576\nsamples = 3\nvalue = 43.367'),
#  Text(0.9555863983344899, 0.5476190476190477, 'X[10] <= 0.463\nsquared_error = 0.01\nsamples = 2\nvalue = 43.9'),
#  Text(0.9528105482303956, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.9583622484385843, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 43.8'),
#  Text(0.9611380985426787, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 42.3'),
#  Text(0.9694656488549618, 0.5952380952380952, 'X[7] <= 0.288\nsquared_error = 0.123\nsamples = 2\nvalue = 46.35'),
#  Text(0.9666897987508675, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 46.7'),
#  Text(0.9722414989590562, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.9777931991672449, 0.6428571428571429, 'X[7] <= 0.331\nsquared_error = 0.722\nsamples = 2\nvalue = 49.15'),
#  Text(0.9750173490631506, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 48.3'),
#  Text(0.9805690492713394, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9861207494795281, 0.6904761904761905, 'X[5] <= 0.879\nsquared_error = 5.007\nsamples = 3\nvalue = 40.7'),
#  Text(0.9833448993754337, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 37.6'),
#  Text(0.9888965995836225, 0.6428571428571429, 'X[8] <= 0.283\nsquared_error = 0.302\nsamples = 2\nvalue = 42.25'),
#  Text(0.9861207494795281, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 42.8'),
#  Text(0.9916724496877168, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 41.7'),
#  Text(0.9944482997918113, 0.7380952380952381, 'X[0] <= 0.002\nsquared_error = 3.063\nsamples = 2\nvalue = 36.95'),
#  Text(0.9916724496877168, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 38.7'),
#  Text(0.9972241498959056, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.9751908396946565, 0.8333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9')]

# %% [markdown]
# ### Report accuracy

# %%
score_train = dt_model.score(X_train, y_train)
score_train # r2
# Out:
# 1.0

# %%
score = dt_model.score(X_test, y_test)
score # r2
# Out:
# 0.7618813123908483

# %% [markdown]
# ### Variable importance plot

# %%
# Get importance
importance = dt_model.feature_importances_
# Adding name of cols
importance = pd.DataFrame(importance, index=X.columns, 
                          columns=["Importance"])

# Sort values
importance = importance.sort_values(by=['Importance'], ascending=False)

importance.plot.bar()

# %% [markdown]
# The plot tells us that **the most relevant variable is RM (average number of rooms per dwelling), followed by LSTAT (% lower status of the population) and DIS (weighted distances to five Boston employment centres).** RM represents ~60% of the relative importance.
#
# If we want to understand the sign of the effect, we can look at the splits and see the direction of each of them based on the decisions.

# %% [markdown]
# We can prune the model to have a simple version and avoid overfitting (in this case is not happening but it's always a good idea to have the smallest possible tree that fits well)

# %% [markdown]
# ### Parameter tuning and cross-validation

# %% [markdown]
# - Sklearn documentation regarding parameters: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html
# - Tutorial on how to tune: https://projector-video-pdf-converter.datacamp.com/6280/chapter5.pdf

# %% [markdown]
#  By tuning parameters, we can prune the tree and maximize the precision. We are going to use gridsearch, but there are other methods to tune (eg randomsearch)
#  Some of the most relevant parameters to tune in a decision tree regressor are:
#  - **maxdepth:** This indicates how deep the tree can be. The deeper the tree, the more splits it has and it captures more information about the data
#  - **min_samples_split:** The minimum number of samples required to split an internal node
#  - **min_samples_leaf:** The minimum number of samples required to be at a leaf node
#  - **max_features:** The number of features to consider when looking for the best split

# %%
# Check current parameters (default in this case as we didn't specify any)
print(dt_model.get_params())
# Out:
# {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 1234, 'splitter': 'best'}

# %%
# Check current depth
dt_model.get_depth()
# Out:
# 20

# %%
# Parameters to tune - ranges
params_dt = {
'max_depth': range(3,11),
'min_samples_leaf': [0.04, 0.06, 0.08],
'max_features': [0.2, 0.4,0.6, 0.8]
}

# %%
# Instantiate a 10-fold CV grid search object using ranges defined and type of scoring to decide best model
grid_dt = GridSearchCV(estimator=dt_model,
param_grid=params_dt,
scoring='r2',
cv=10,
n_jobs=-1) # -1 means using all processors.

# %%
# Estimate models - can take long depending on data size
grid_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=1234),
#              n_jobs=-1,
#              param_grid={'max_depth': range(3, 11),
#                          'max_features': [0.2, 0.4, 0.6, 0.8],
#                          'min_samples_leaf': [0.04, 0.06, 0.08]},
#              scoring='r2')

# %%
# Extract best hyperparameters
best_hyperparams = grid_dt.best_params_
print('Best hyperparameters:\n', best_hyperparams)
# Out:
# Best hyperparameters:
#  {'max_depth': 5, 'max_features': 0.4, 'min_samples_leaf': 0.06}

# %%
# Extract best CV score
best_CV_score = grid_dt.best_score_
best_CV_score
# Out:
# 0.7304874275527843

# %%
# Extract best model
best_model = grid_dt.best_estimator_
# Evaluate test set accuracy
test_acc = best_model.score(X_test,y_test)
# Print test set accuracy
print("Test set accuracy of best model: {:.3f}".format(test_acc))
# Out:
# Test set accuracy of best model: 0.740

# %%
# Plot tree
fig, ax = plt.subplots(figsize=(12, 12))
tree.plot_tree(best_model, fontsize=10, feature_names=X.columns)
plt.show()

# %%
# Variable importance
importance = best_model.feature_importances_
# Adding name of cols
importance = pd.DataFrame(importance, index=X.columns, 
                          columns=["Importance"])

# Sort values
importance = importance.sort_values(by=['Importance'], ascending=False)

importance.plot.bar()

# %%
y_pred = best_model.predict(X_test)
mape(y_test, y_pred)
# Out:
# 16.0885340405891

# %% [markdown]
# In conclusion, we get 2 good models one pruned, easier to explain but with less accuracy and another more complex but high accuracy. Depending on the purpose, we could choose the right one (eg if prediction is the goal, higher accuracy might be the metric to follow but if we are focused on describe what is impacting prices, a shorter version of the model might be enough)
